# %%
# !pip install ipython-sql

# %%
# !pip install mysqlclient

# %%
# !pip install ipython-sql

# %%
# !pip install pymysql

# %%
import pandas as pd 
import numpy as np
import os
import mysql.connector
import pymysql

# %%
df=pd.read_csv("C:\\Users\\dilee\\OneDrive\\Desktop\\project npi\\MODIFIED FINAL 1.csv")

# %%
df
# Out:
#             NPI Entity Type Code  Replacement NPI  \
# 0    1003542069  2, Organization              NaN
# 1    1912633975  2, Organization              NaN
# 2    1578207668  2, Organization              NaN
# 3    1649906603  2, Organization              NaN
# 4    1790417673    1, Individual              NaN
# ..          ...              ...              ...
# 495  1295454627    1, Individual              NaN
# 496  1013636448    1, Individual              NaN
# 497  1104545532  2, Organization              NaN
# 498  1922727353    1, Individual              NaN
# 499  1003535436    1, Individual              NaN
#
#     Employer Identification Number (EIN)  \
# 0                              <UNAVAIL>
# 1                              <UNAVAIL>
# 2                              <UNAVAIL>
# 3                              <UNAVAIL>
# 4                                    NaN
# ..                                   ...
# 495                                  NaN
# ...

# %%
df1 = df[['NPI', 'Entity Type Code','Is Sole Proprietor','Is Organization Subpart','Provider Other Last Name Type Code','Provider Other Organization Name Type Code','NPI Deactivation Reason Code','Provider Gender Code','Provider Business Mailing Address State Name','Provider Name Prefix Text']]

# %%
df1
# Out:
#             NPI Entity Type Code Is Sole Proprietor Is Organization Subpart  \
# 0    1003542069  2, Organization                NaN                   N, No
# 1    1912633975  2, Organization                NaN                   N, No
# 2    1578207668  2, Organization                NaN                   N, No
# 3    1649906603  2, Organization                NaN                   N, No
# 4    1790417673    1, Individual              N, No                     NaN
# ..          ...              ...                ...                     ...
# 495  1295454627    1, Individual              N, No                     NaN
# 496  1013636448    1, Individual             Y, Yes                     NaN
# 497  1104545532  2, Organization                NaN                   N, No
# 498  1922727353    1, Individual             Y, Yes                     NaN
# 499  1003535436    1, Individual              N, No                     NaN
#
#     Provider Other Last Name Type Code  \
# ...

# %%
import mysql.connector as msql
from mysql.connector import Error
try:
    conn = msql.connect(host='localhost', database='npiproject', user='root', password='root')
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)
        cursor.execute('DROP TABLE IF EXISTS NPI_data;')
        print('Creating table....')
# in the below line please pass the create table statement which you want #to create
        cursor.execute("CREATE TABLE NPI_data(NPI int(200),Entity_Type_Code varchar(255),Is_Sole_Proprietor varchar(255),Is_Organization_Subpart varchar(255),Provider_Business_Mailing_Address_Country_Code varchar(255),Provider_Other_Last_Name_Type_Code varchar(255),Provider_Other_Organization_Name_Type_Code varchar(255),NPI_Deactivation_Reason_Code varchar(255),Provider_Gender_Code varchar(255),Provider_Business_Mailing_Address_State_Name varchar(255),Provider_Name_Prefix_Text varchar(255))")
        print("Table is created....")
        #loop through the data frame
        for i,row in df1.iterrows():
            #here %S means string values 
            sql = "INSERT INTO npiproject.npi_data VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"
            cursor.execute(sql, tuple(row))
            print("Record inserted")
            # the connection is not auto committed by default, so we must commit to save our changes
            conn.commit()
except Error as e:
            print("Error while connecting to MySQL", e)
